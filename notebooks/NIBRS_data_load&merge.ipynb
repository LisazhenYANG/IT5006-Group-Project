# %%
import pandas as pd
import os

def load_nibrs_folder(folder_path):

    incident = pd.read_csv(
        os.path.join(folder_path, "NIBRS_incident.csv"),
        encoding="latin1",
        low_memory=False
    )

    offense = pd.read_csv(
        os.path.join(folder_path, "NIBRS_OFFENSE.csv"),
        encoding="latin1",
        low_memory=False
    )

    offense_type = pd.read_csv(
        os.path.join(folder_path, "NIBRS_OFFENSE_TYPE.csv"),
        encoding="latin1",
        low_memory=False
    )

    agencies = pd.read_csv(
        os.path.join(folder_path, "agencies.csv"),
        encoding="latin1",
        low_memory=False
    )

    location = pd.read_csv(
        os.path.join(folder_path, "NIBRS_LOCATION_TYPE.csv"),
        encoding="latin1",
        low_memory=False
    )

    # merge 
    df = incident.merge(agencies, on="agency_id", how="left")
    df = df.merge(offense, on="incident_id", how="left")
    df = df.merge(offense_type, on="offense_code", how="left")
    df = df.merge(location, on="location_id", how="left")

    return df

# %%
# incident = pd.read_csv(r"D:\nuscourses\IT5006\NIBRS DATASET\CA-2021\NIBRS_incident.csv", encoding="latin1")
# print(incident.head())
# print(incident.columns.tolist())

# %%
base_dir = r"D:\nuscourses\IT5006\NIBRS DATASET"

folders = [
    "CA-2021", "CA-2022", "CA-2023", "CA-2024",
    "TX-2021", "TX-2022", "TX-2023", "TX-2024",
    "NY-2021", "NY-2022", "NY-2023", "NY-2024"
]

all_dfs = []

for folder in folders:
    folder_path = os.path.join(base_dir, folder)
    df_temp = load_nibrs_folder(folder_path)
    df_temp["source_folder"] = folder
    all_dfs.append(df_temp)

df_all = pd.concat(all_dfs, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 13
#      11 for folder in folders:
#      12     folder_path = os.path.join(base_dir, folder)
# ---> 13     df_temp = load_nibrs_folder(folder_path)
#      14     df_temp["source_folder"] = folder
#      15     all_dfs.append(df_temp)
#
# Cell In[1], line 6, in load_nibrs_folder(folder_path)
#       4 def load_nibrs_folder(folder_path):
# ----> 6     incident = pd.read_csv(
#       7         os.path.join(folder_path, "NIBRS_incident.csv"),
#       8         encoding="latin1",
#       9         low_memory=False
#      10     )
#      12     offense = pd.read_csv(
#      13         os.path.join(folder_path, "NIBRS_OFFENSE.csv"),
#      14         encoding="latin1",
#      15         low_memory=False
#      16     )
#      18     offense_type = pd.read_csv(
#      19         os.path.join(folder_path, "NIBRS_OFFENSE_TYPE.csv"),
#      20         encoding="latin1",
#      21         low_memory=False
#      22     )
#
# File ~/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/venv/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\nuscourses\\IT5006\\NIBRS DATASET/CA-2021/NIBRS_incident.csv'

# %%
df_all.head(5)
# Out:
#    data_year_x  agency_id  incident_id  nibrs_month_id cargo_theft_flag  \
# 0         2021       1516    141774651        40314544                f
# 1         2021       1516    136500530         3105156                f
# 2         2021       1516    136580646         3105156                f
# 3         2021       1516    136530548         3105156                f
# 4         2021       1516    136516079         3105156                f
#
#            submission_date incident_date report_date_flag  incident_hour  \
# 0  2021-09-03 15:14:09.574    2021-08-26                f           12.0
# 1  2021-04-01 16:21:26.134    2021-01-01                f            0.0
# 2  2021-04-07 16:16:36.326    2021-01-01                f            0.0
# 3  2021-04-06 17:20:40.595    2021-01-01                f            1.0
# 4   2021-04-03 00:07:12.33    2021-01-01                f            0.0
#
#    cleared_except_id  ...        offense_name crime_against  ct_flag hc_flag  \
# 0                  6  ...                Rape        Person        f       t
# 1                  6  ...  Aggravated Assault        Person        f       t
# 2                  6  ...      Simple Assault        Person        f       t
# 3                  6  ...      Simple Assault        Person        f       t
# 4                  2  ...      Simple Assault        Person        f       t
#
#    hc_code  offense_category_name  offense_group location_code  \
# 0       02           Sex Offenses              A            20
# 1       04       Assault Offenses              A            13
# 2       09       Assault Offenses              A            20
# 3       09       Assault Offenses              A            25
# 4       09       Assault Offenses              A             7
#
#                         location_name source_folder
# 0                      Residence/Home       CA-2021
# 1  Highway/Road/Alley/Street/Sidewalk       CA-2021
# 2                      Residence/Home       CA-2021
# 3                       Other/Unknown       CA-2021
# 4                   Convenience Store       CA-2021
#
# [5 rows x 90 columns]

# %%
df_all.to_csv("../data/nibrs/nibrs_merged.csv", index=False)

# %%
df_all["year"] = df_all["data_year_x"]
df_all = df_all.drop(columns=[col for col in df_all.columns if "data_year" in col])

# %%
use_cols = [
    "agency_id",
    "year",
    "offense_name",
    "location_name",
    "state_name",
    "region_name",
    "agency_type_name"
]

df_use = df_all[use_cols].copy()

# %%
df_use.to_csv("../data/nibrs/nibrs_use.csv", index=False)
